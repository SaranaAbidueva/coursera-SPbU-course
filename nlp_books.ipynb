# %%
import sqlalchemy
import pandas as pd

db = sqlalchemy.create_engine('sqlite:///books_db.sqlite')
df = pd.read_sql_query('select chunk_id, author, text from chunk', 
                       db, index_col='chunk_id')

df.head(5)
# Out:
#                          author  \
# chunk_id
# 1         Иван Алексеевич Бунин
# 2         Иван Алексеевич Бунин
# 3         Иван Алексеевич Бунин
# 4         Иван Алексеевич Бунин
# 5         Иван Алексеевич Бунин
#
#                                                        text
# chunk_id
# 1         В знак веры в жизнь вечную, в воскресение из м...
# 2         Ибо он, этот волчец, воистину чудесен. Сорванн...
# 3         Так утешаюсь и я, воскрешая в себе те светонос...
# 4         Роза Иерихона. В живую воду сердца, в чистую в...
# 5         Золотилось солнце на востоке, за туманной синь...

# %%
df
# Out:
#                            author  \
# chunk_id
# 1           Иван Алексеевич Бунин
# 2           Иван Алексеевич Бунин
# 3           Иван Алексеевич Бунин
# 4           Иван Алексеевич Бунин
# 5           Иван Алексеевич Бунин
# ...                           ...
# 50002     Иван Сергеевич Тургенев
# 50003     Иван Сергеевич Тургенев
# 50004     Иван Сергеевич Тургенев
# 50005     Иван Сергеевич Тургенев
# 50006     Иван Сергеевич Тургенев
#
#                                                        text
# chunk_id
# 1         В знак веры в жизнь вечную, в воскресение из м...
# 2         Ибо он, этот волчец, воистину чудесен. Сорванн...
# 3         Так утешаюсь и я, воскрешая в себе те светонос...
# 4         Роза Иерихона. В живую воду сердца, в чистую в...
# 5         Золотилось солнце на востоке, за туманной синь...
# ...                                                     ...
# 50002     Очень строгая хозяйка — сошлась с мужем характ...
# 50003     4. Евлампия Мартыновна Харлова.\nЭта похожа на...
# 50004     5. Гаврила Федулыч Житков.\nКадетина, армейщин...
# 50005     6. Сувенир Бычков.\nНастоящее имя его неизвест...
# 50006     С одной стороны рта зубов нет, так что все лиц...
#
# [50006 rows x 2 columns]

# %%
import pymorphy2
import re

morph = pymorphy2.MorphAnalyzer()

def is_cyr_word(word):
    for ch in word:
        if not ('а' <= ch <= 'я'):
            return False
    return True

def process_text(text):        
    lower = (word.lower() for word in re.split(r'\W+', text))
    cyr = (word for word in lower if len(word) > 0 and is_cyr_word(word))
    norm_form = (morph.parse(word)[0].normal_form for word in cyr)
        
    return ' '.join(norm_form)

df['text'] = df['text'].map(process_text)

# %%
for text in df['text']:
    words = text.split(' ') 
words
# Out:
# ['с',
#  'один',
#  'сторона',
#  'рот',
#  'зуб',
#  'нет',
#  'так',
#  'что',
#  'всё',
#  'лицо',
#  'несколько',
#  'скривиться',
#  'очень',
#  'презирать',
#  'любимый',
#  'поговорка',
#  'а',
#  'вот',
#  'позволить',
#  'я',
#  'сичас',
#  'сичас',
#  'да',
#  'что',
#  'сичас',
#  'рука',
#  'назад',
#  'как',
#  'приказать',
#  'трус',
#  'естественный',
#  'я',
#  'взять',
#  'с',
#  'себя',
#  'когда',
#  'послать',
#  'он',
#  'харлов',
#  'г',
#  'н',
#  'квицинский']

# %%
df
# Out:
#                            author  \
# chunk_id
# 1           Иван Алексеевич Бунин
# 2           Иван Алексеевич Бунин
# 3           Иван Алексеевич Бунин
# 4           Иван Алексеевич Бунин
# 5           Иван Алексеевич Бунин
# ...                           ...
# 50002     Иван Сергеевич Тургенев
# 50003     Иван Сергеевич Тургенев
# 50004     Иван Сергеевич Тургенев
# 50005     Иван Сергеевич Тургенев
# 50006     Иван Сергеевич Тургенев
#
#                                                        text
# chunk_id
# 1         в знак вера в жизнь вечный в воскресение из мё...
# 2         ибо он этот волчец воистину чудесный сорвать и...
# 3         так утешаться и я воскрешать в себя тот светон...
# 4         роза иерихон в живой вода сердце в чистый влаг...
# 5         золотиться солнце на восток за туманный синь д...
# ...                                                     ...
# 50002     очень строгий хозяйка сойтись с муж характер г...
# 50003     евлампий мартынович харлов этот похожий на оте...
# 50004     гаврил федулович житков кадетина армейщина дос...
# 50005     сувенир бычков настоящий имя он неизвестно про...
# 50006     с один сторона рот зуб нет так что всё лицо не...
#
# [50006 rows x 2 columns]

# %%
import numpy as np

# %%
count_dict = {}
for text in df['text']:
    words = text.split(' ')
    words_unique = np.unique(words)
    for word in words_unique:
        if word in count_dict.keys():
            count_dict[word] += 1
        else: count_dict[word] = 1 
count_dict
# Out:
# {'безлюдный': 41,
#  'в': 33040,
#  'вера': 1028,
#  'вечный': 237,
#  'воскресение': 114,
#  'восток': 99,
#  'встречаться': 111,
#  'гроб': 214,
#  'да': 7212,
#  'древность': 22,
#  'ещё': 6102,
#  'жизнь': 3086,
#  'жёсткий': 94,
#  'знак': 567,
#  'иерихон': 4,
#  'из': 8043,
#  'каменистый': 17,
#  'класть': 220,
#  'клубок': 14,
#  'колючий': 25,
#  'могила': 227,
#  'море': 458,
#  'мёртвый': 495,
#  'на': 25155,
#  'назвать': 214,
#  'наш': 2481,
#  'ниже': 104,
#  'перекатить': 17,
#  'песок': 243,
#  'подобный': 268,
#  'поле': 1182,
#  'поросль': 5,
#  'предгорие': 3,
#  'пустынный': 63,
#  'роза': 126,
#  'синайский': 4,
#  'стебель': 24,
#  'странно': 315,
#  'сухой': 319,
#  'только': 6319,
#  'что': 24295,
#  'этот': 6852,
#  'бедный': 627,
#  'быть': 19642,
#  'верста': 336,
#  'вода': 1089,
#  'воистину': 12,
#  'волчец': 2,
#  'гибель': 101,
#  'год': 2413,
#  'давать': 1106,
#  'жить': 2625,
#  'за': 9029,
#  'и': 42438,
#  'ибо': 180,
#  'когда': 4930,
#  'лежать': 1397,
#  'листочек': 10,
#  'мелкий': 321,
#  'мир': 868,
#  'мочь': 6134,
#  'начинать': 577,
#  'нет': 5542,
#  'но': 11624,
#  'он': 27292,
#  'от': 7900,
#  'положить': 668,
#  'радоваться': 200,
#  'распускаться': 13,
#  'родина': 157,
#  'розовый': 162,
#  'свой': 10140,
#  'сердце': 1740,
#  'серый': 302,
#  'смерть': 708,
#  'сорвать': 74,
#  'странник': 60,
#  'то': 12330,
#  'тот': 7290,
#  'тотчас': 900,
#  'тысяча': 540,
#  'унести': 95,
#  'утешаться': 25,
#  'цвет': 337,
#  'человеческий': 320,
#  'чем': 2492,
#  'чудесный': 100,
#  'благословенный': 15,
#  'бог': 2387,
#  'брачный': 13,
#  'бывший': 294,
#  'вместе': 894,
#  'воскрешать': 6,
#  'где': 3179,
#  'господин': 1280,
#  'дальний': 252,
#  'день': 3218,
#  'до': 4050,
#  'древний': 155,
#  'земля': 1692,
#  'иисус': 37,
#  'кто': 3617,
#  'мой': 5197,
#  'надежда': 638,
#  'некогда': 237,
#  'нога': 1591,
#  'о': 6325,
#  'паломничество': 4,
#  'первый': 1929,
#  'полдень': 150,
#  'путешествие': 109,
#  'рука': 5202,
#  'с': 23121,
#  'светоносный': 3,
#  'святой': 271,
#  'себя': 6866,
#  'сила': 1501,
#  'совершать': 40,
#  'солнце': 855,
#  'спутница': 19,
#  'стоять': 1872,
#  'страна': 173,
#  'странствие': 16,
#  'ступать': 372,
#  'судить': 204,
#  'так': 8678,
#  'тем': 1705,
#  'христос': 127,
#  'я': 21866,
#  'влага': 63,
#  'вот': 4734,
#  'дивно': 18,
#  'живой': 938,
#  'забвение': 51,
#  'заветный': 28,
#  'злак': 13,
#  'иссохнуть': 8,
#  'иссякнуть': 9,
#  'корень': 76,
#  'любовь': 1123,
#  'навеки': 90,
#  'нежность': 136,
#  'неотвратимый': 8,
#  'опять': 3155,
#  'оскудеть': 5,
#  'отдалиться': 11,
#  'печаль': 142,
#  'погружать': 9,
#  'покрыть': 218,
#  'прах': 95,
#  'прозябать': 11,
#  'прошлое': 115,
#  'уже': 4533,
#  'час': 1606,
#  'чистый': 486,
#  'без': 2653,
#  'белый': 676,
#  'берег': 631,
#  'бодрый': 56,
#  'глядеть': 2180,
#  'гора': 788,
#  'горный': 36,
#  'город': 1426,
#  'далёкий': 838,
#  'железнодорожный': 75,
#  'золотиться': 6,
#  'извозчик': 169,
#  'иней': 21,
#  'канун': 15,
#  'который': 6993,
#  'лес': 643,
#  'лёгкий': 545,
#  'мороз': 100,
#  'наездить': 3,
#  'невысокий': 42,
#  'низменность': 7,
#  'петроградский': 4,
#  'по': 9925,
#  'поезд': 401,
#  'прийти': 1540,
#  'рождество': 35,
#  'русский': 652,
#  'седок': 18,
#  'синь': 55,
#  'снег': 404,
#  'снежный': 81,
#  'станция': 419,
#  'туманный': 63,
#  'тянуться': 128,
#  'утро': 803,
#  'бархатный': 54,
#  'берет': 18,
#  'блестящий': 177,
#  'большой': 2584,
#  'глаз': 3842,
#  'гостиница': 112,
#  'гость': 820,
#  'длинный': 616,
#  'доха': 21,
#  'ждать': 843,
#  'зеленоватый': 17,
#  'изумлённый': 41,
#  'к': 12916,
#  'каштановый': 11,
#  'крыльцо': 336,
#  'кудри': 35,
#  'мех': 33,
#  'не': 29408,
#  'падать': 273,
#  'пенсне': 17,
#  'площадь': 170,
#  'под': 2593,
#  'подъехать': 85,
#  'праздник': 152,
#  'прибрать': 40,
#  'просторный': 66,
#  'против': 460,
#  'пусто': 64,
#  'ряд': 239,
#  'старый': 1322,
#  'тихо': 933,
#  'торговый': 45,
#  'чёрный': 798,
#  'бородач': 3,
#  'вести': 405,
#  'внимание': 479,
#  'громко': 326,
#  'дорога': 1552,
#  'желать': 832,
#  'заграничный': 31,
#  'козлы': 24,
#  'коридор': 164,
#  'коридорный': 53,
#  'крякать': 12,
#  'молодой': 1365,
#  'набавить': 5,
#  'нести': 285,
#  'номер': 155,
#  'обратить': 208,
#  'они': 10625,
#  'показать': 505,
#  'предоставить': 48,
#  'притворно': 27,
#  'промёрзнуть': 6,
#  'расплатиться': 16,
#  'рыжий': 75,
#  'самый': 1636,
#  'светлый': 318,
#  'сказать': 11206,
#  'следовать': 380,
#  'торжествёный': 2,
#  'чемодан': 161,
#  'шаг': 839,
#  'широкий': 412,
#  'глубокий': 472,
#  'два': 3078,
#  'дверь': 1569,
#  'комната': 1981,
#  'небольшой': 515,
#  'нижний': 148,
#  'обширный': 61,
#  'однако': 916,
#  'окно': 1362,
#  'очень': 2563,
#  'почётный': 38,
#  'прихожая': 39,
#  'причина': 350,
#  'распахнуть': 32,
#  'смягчённый': 5,
#  'состоять': 228,
#  'спокойно': 245,
#  'стекло': 200,
#  'стена': 580,
#  'тепло': 293,
#  'толстый': 193,
#  'уютный': 54,
#  'янтарно': 4,
#  'боковой': 47,
#  'взглянуть': 783,
#  'вынуть': 241,
#  'дата': 9,
#  'двадцать': 451,
#  'девятьсот': 28,
#  'декабрь': 48,
#  'десятый': 73,
#  'должный': 1780,
#  'запомнить': 63,
#  'золотой': 198,
#  'карман': 373,
#  'куртка': 57,
#  'мельком': 56,
#  'нос': 437,
#  'один': 7187,
#  'ответить': 1206,
#  'половина': 356,
#  'прищурить': 31,
#  'продолжать': 1654,
#  'ровно': 179,
#  'слушать': 1192,
#  'снова': 591,
#  'сь': 9,
#  'ты': 9132,
#  'устраивать': 20,
#  'художник': 184,
#  'часы': 228,
#  'четвёртый': 159,
#  'шестнадцатый': 13,
#  'бессмертный': 29,
#  'благодарить': 293,
#  'вещь': 521,
#  'взять': 2122,
#  'война': 492,
#  'грозно': 58,
#  'дело': 3172,
#  'завет': 19,
#  'исполнить': 221,
#  'краска': 156,
#  'любезный': 206,
#  'написать': 642,
#  'невозможно': 208,
#  'ни': 2941,
#  'она': 16685,
#  'подарить': 143,
#  'покорнейше': 30,
#  'провезти': 6,
#  'совершенно': 702,
#  'точно': 1235,
#  'холст': 24,
#  'чудовищный': 24,
#  'благой': 22,
#  'ведать': 102,
#  'весь': 7536,
#  'взмахнуть': 22,
#  'воскликнуть': 544,
#  'всё': 5763,
#  'говорить': 7079,
#  'откровение': 10,
#  'отчеканивать': 11,
#  'понять': 1084,
#  'слово': 3812,
#  'слышать': 1074,
#  'смотреть': 1900,
#  'собеседник': 71,
#  'театрально': 8,
#  'узнать': 1052,
#  'упор': 55,
#  'хорошо': 1517,
#  'через': 1613,
#  'это': 14136,
#  'важно': 89,
#  'выше': 263,
#  'добавить': 63,
#  'друг': 1644,
#  'зашагать': 23,
#  'кивнуть': 100,
#  'кинуться': 55,
#  'лестница': 292,
#  'надеть': 294,
#  'направиться': 149,
#  'отворять': 75,
#  'площадка': 65,
#  'приостановиться': 43,
#  'равный': 58,
#  'рождение': 85,
#  'таинство': 19,
#  'человек': 6564,
#  'белые': 157,
#  'висеть': 217,
#  'голубой': 164,
#  'голый': 231,
#  'густой': 265,
#  'гусь': 50,
#  'жирный': 48,
#  'загривок': 4,
#  'застывший': 19,
#  'зелёный': 290,
#  'индейка': 18,
#  'иня': 7,
#  'крошиться': 7,
#  'лавка': 226,
#  'мясной': 28,
#  'мёрзлый': 16,
#  'небо': 806,
#  'нежно': 135,
#  'ободняться': 2,
#  'осыпаться': 10,
#  'ощипанный': 9,
#  'проволока': 24,
#  'разрез': 12,
#  'рисоваться': 40,
#  'рябчик': 16,
#  'свинья': 99,
#  'сизый': 15,
#  'совсем': 1387,
#  'солнечно': 9,
#  'стать': 4145,
#  'телеграфный': 24,
#  'темно': 204,
#  'толпиться': 77,
#  'тушить': 25,
#  'у': 10046,
#  'улица': 890,
#  'целый': 880,
#  'ёлка': 28,
#  'больший': 1001,
#  'вид': 1115,
#  'возле': 456,
#  'деревянный': 268,
#  'игрушка': 43,
#  'конь': 244,
#  'лоток': 12,
#  'одетый': 268,
#  'петух': 90,
#  'подпоясать': 19,
#  'покрикивать': 12,
#  'пряник': 26,
#  'русь': 34,
#  'рыба': 186,
#  'самодельный': 22,
#  'толсто': 3,
#  'торговец': 17,
#  'торговка': 17,
#  'туго': 50,
#  'узнавать': 166,
#  'шагать': 126,
#  'быстро': 847,
#  'велеть': 523,
#  'главный': 336,
#  'дом': 2669,
#  'ехать': 1032,
#  'каляный': 4,
#  'колено': 409,
#  'меринок': 3,
#  'мотнуть': 14,
#  'накатать': 3,
#  'одиннадцать': 81,
#  'подозвать': 31,
#  'полость': 10,
#  'понести': 97,
#  'работа': 911,
#  'садиться': 551,
#  'санки': 12,
#  'свободный': 243,
#  'сытый': 95,
#  'тяжёлый': 400,
#  'холодное': 107,
#  'шапка': 276,
#  'двенадцать': 124,
#  'забытый': 101,
#  'знакомый': 606,
#  'изволить': 415,
#  'как': 15790,
#  'место': 2161,
#  'называться': 160,
#  'оглядываться': 152,
#  'основательно': 14,
#  'повторить': 696,
#  'полный': 762,
#  'пьяцца': 2,
#  'свет': 1498,
#  'спрашивать': 787,
#  'спросить': 3690,
#  'барин': 396,
#  'бы': 5350,
#  'вы': 11046,
#  'другой': 4336,
#  'же': 8774,
#  'куда': 1475,
#  'лошадь': 960,
#  'магазин': 112,
#  'мы': 6786,
#  'нанять': 80,
#  'недоумение': 204,
#  'ну': 3696,
#  'осадить': 25,
#  'понимать': 1448,
#  'приказать': 409,
#  'разбежаться': 31,
#  'сребреник': 2,
#  'твой': 1336,
#  'убираться': 42,
#  'хороший': 2436,
#  'художественный': 34,
#  'черта': 570,
#  'багет': 6,
#  'блуждать': 55,
#  'бросить': 596,
#  'войти': 1185,
#  'волочиться': 10,
#  'вылезти': 45,
#  'золочёный': 14,
#  'назад': 903,
#  'неловко': 187,
#  'пойти': 2652,
#  'посередине': 14,
#  'поспешно': 215,
#  'прочь': 283,
#  'распахнуться': 26,
#  'растерянно': 17,
#  'сани': 94,
#  'сторона': 1609,
#  'страдальчески': 8,
#  'трёхрублёвка': 2,
#  'увидать': 294,
#  'ах': 1172,
#  'вообще': 363,
#  'вопрос': 875,
#  'вряд': 19,
#  'голова': 3243,
#  'для': 3516,
#  'именно': 603,
#  'ли': 3583,
#  'масляный': 16,
#  'найти': 755,
#  'непритворный': 10,
#  'неужели': 374,
#  'обои': 31,
#  'отчаяние': 267,
#  'рама': 75,
#  'сейчас': 1790,
#  'схватиться': 49,
#  'торговать': 77,
#  'ужасно': 312,
#  'барышня': 201,
#  'брать': 737,
#  'вежливость': 30,
#  'встрепенуться': 65,
#  'выйти': 1973,
#  'здесь': 2009,
#  'извиняться': 58,
#  'испуг': 261,
#  'поднять': 716,
#  'покупатель': 24,
#  'правый': 305,
#  'преувеличить': 12,
#  'простить': 415,
#  'ради': 414,
#  'раз': 2801,
#  'шпалера': 5,
#  'акварельный': 4,
#  'бумажный': 43,
#  'вскочить': 306,
#  'затем': 665,
#  'знание': 103,
#  'карандаш': 72,
#  'картон': 17,
#  'купить': 311,
#  'лист': 284,
#  'несколько': 1518,
#  'палитра': 18,
#  'погнать': 25,
#  'позвонить': 83,
#  'цветной': 29,
#  'шершавый': 15,
#  'явиться': 462,
#  'а': 17659,
#  'акварель': 5,
#  'век': 321,
#  'внезапно': 240,
#  'восторг': 233,
#  'железный': 302,
#  'какой': 6081,
#  'кесарев': 2,
#  'кесарь': 3,
#  'нигде': 166,
#  'пещерный': 2,
#  'подумать': 1347,
#  'принести': 516,
#  'просиять': 30,
#  'протягивать': 94,
#  'стакан': 206,
#  'увы': 49,
#  'алебастровый': 3,
#  'бледный': 426,
#  'волос': 651,
#  'выразить': 136,
#  'высоко': 192,
#  'готовность': 44,
#  'графин': 24,
#  'даже': 2598,
#  'дыхание': 201,
#  'закинуть': 52,
#  'крепко': 236,
#  'кровать': 281,
#  'лицо': 3688,
#  'маска': 24,
#  'минута': 1558,
#  'навзничь': 44,
#  'неизменный': 38,
#  'подушка': 218,
#  'похоже': 113,
#  'разметать': 8,
#  'свежеть': 47,
#  'серо': 34,
#  'слышный': 322,
#  'спальня': 175,
#  'спасть': 499,
#  'уйти': 1198,
#  'услуга': 78,
#  'худой': 200,
#  'брат': 1085,
#  'быстрый': 216,
#  'военный': 257,
#  'вострый': 18,
#  'время': 3146,
#  'держать': 644,
#  'жена': 1457,
#  'звонить': 74,
#  'иван': 1643,
#  'матвеевич': 194,
#  'отметить': 23,
#  'паспорт': 28,
#  'полиция': 67,
#  'помереть': 140,
#  'правильный': 103,
#  'присматривать': 8,
#  'спать': 1040,
#  'ухо': 431,
#  'хозяин': 524,
#  'чудо': 123,
#  'шёпотом': 152,
#  'бывать': 710,
#  'грусть': 159,
#  'дать': 2219,
#  'медленно': 469,
#  'одарить': 11,
#  'подхватить': 237,
#  'прильнуть': 31,
#  'самовар': 162,
#  'сделать': 1964,
#  'уходить': 740,
#  'чувствоваться': 62,
#  'беременный': 17,
#  'восьмой': 70,
#  'всяческий': 16,
#  'есть': 3708,
#  'закричать': 567,
#  'каков': 188,
#  'меж': 88,
#  'месяц': 508,
#  'неделя': 534,
#  'одиссей': 3,
#  'почти': 1560,
#  'появиться': 208,
#  'предпринять': 27,
#  'представить': 328,
#  'пройти': 1112,
#  'разбудить': 165,
#  'рогатка': 5,
#  'страшный': 548,
#  'шесть': 278,
#  'давеча': 162,
#  'делать': 1979,
#  'дух': 544,
#  'зычный': 5,
#  'кой': 442,
#  'кончить': 364,
#  'крик': 269,
#  'настроение': 117,
#  'ночь': 1341,
#  'оторопеть': 12,
#  'помочь': 326,
#  'при': 1533,
#  'приготовить': 161,
#  'работать': 708,
#  'радостный': 149,
#  'такой': 4952,
#  'три': 1418,
#  'успокаиваться': 33,
#  'бездна': 72,
#  'восемь': 232,
#  'довольно': 690,
#  'долго': 1071,
#  'иначе': 338,
#  'надо': 2323,
#  'нужный': 536,
#  'писать': 915,
#  'подойти': 831,
#  'подсвечник': 16,
#  'покачать': 169,
#  'преддиванный': 2,
#  'примести': 2,
#  'разный': 477,
#  'свеча': 200,
#  'семь': 223,
#  'скатерть': 55,
#  'спустя': 179,
#  'стащить': 34,
#  'стоить': 962,
#  'стол': 1438,
#  'твёрдо': 140,
#  'всякий': 1311,
#  'десять': 534,
#  'досадный': 86,
#  'заволноваться': 16,
#  'зеркало': 188,
#  'крайний': 367,
#  'мера': 475,
#  'нету': 445,
#  'низость': 29,
#  'нужно': 1181,
#  'отражение': 25,
#  'поставить': 451,
#  'преграда': 22,
#  'увеличить': 18,
#  'ба': 41,
#  'бормотать': 228,
#  'бояться': 1006,
#  'выбрасывать': 8,
#  'газета': 180,
#  'застелить': 5,
#  'куча': 188,
#  'надевать': 118,
#  'нибыть': 2653,
#  'поглощать': 16,
#  'покрепче': 14,
#  'помогать': 177,
#  'потащить': 35,
#  'предусмотрительно': 2,
#  'ронять': 26,
#  'теперь': 4488,
#  'указанный': 23,
#  'уставить': 53,
#  'девять': 97,
#  'зажечь': 121,
#  'зловещий': 33,
#  'кнопка': 13,
#  'обилие': 22,
#  'огонь': 758,
#  'открыть': 442,
#  'оттуда': 356,
#  'пол': 620,
#  'праздничный': 47,
#  'прикрепить': 11,
#  'принять': 670,
#  'разложить': 35,
#  'расставить': 61,
#  'странный': 595,
#  'али': 45,
#  'вон': 678,
#  'воображать': 153,
#  'горько': 86,
#  'дитя': 127,
#  'идти': 2977,
#  'кушать': 178,
#  'осторожно': 230,
#  'течь': 120,
#  'угол': 592,
#  'усмехнуться': 195,
#  'ходить': 1322,
#  'альбом': 32,
#  'бельё': 159,
#  'вдруг': 2975,
#  'возобновить': 29,
#  'вскричать': 219,
#  'вытащить': 96,
#  'детский': 276,
#  'запустить': 48,
#  'кресло': 392,
#  'наклониться': 100,
#  'останавливаться': 262,
#  'память': 329,
#  'повиснуть': 41,
#  'резко': 129,
#  'сесть': 837,
#  'сперва': 176,
#  'страх': 456,
#  'внутренность': 54,
#  'возвышение': 23,
#  'выпуклый': 23,
#  'гладкий': 63,
#  'женщина': 1504,
#  'камень': 286,
#  'посредине': 41,
#  'пустой': 591,
#  'свод': 40,
#  'снимка': 2,
#  'сомкнутый': 2,
#  'сукно': 47,
#  'траурный': 18,
#  'фотографический': 12,
#  'часовня': 34,
#  'броситься': 523,
#  'вглядываться': 123,
#  'галстук': 42,
#  'дно': 121,
#  'исказиться': 11,
#  'искать': 526,
#  'кинуть': 27,
#  'ковёр': 103,
#  'напряжённо': 47,
#  'носка': 18,
#  'острый': 85,
#  'перерыть': 5,
#  'покойный': 292,
#  'разбросать': 63,
#  'рубашка': 163,
#  'ужас': 420,
#  'вырезать': 22,
#  'голос': 1990,
#  'забыть': 845,
#  'кисть': 85,
#  'клок': 43,
#  'несчастный': 268,
#  'нож': 107,
#  'перочинный': 9,
#  'перу': 5,
#  'подбежать': 65,
#  'полжизни': 12,
#  'пошарить': 14,
#  'привязать': 58,
#  'разве': 872,
#  'сотворить': 22,
#  'топнуть': 28,
#  'хриплый': 37,
#  'щепка': 24,
#  'бросать': 212,
#  'взгляд': 939,
#  'вздуться': 8,
#  'висок': 57,
#  'вперять': 4,
#  'дрожать': 373,
#  'жара': 152,
#  'жила': 45,
#  'напряжение': 106,
#  'низко': 101,
#  'отдых': 121,
#  'откидываться': 12,
#  'сильный': 622,
#  'смочься': 2,
#  'снять': 324,
#  'трудиться': 122,
#  'туман': 191,
#  'уверенный': 153,
#  'удар': 237,
#  'цветистый': 5,
#  'шея': 369,
#  'безнадёжно': 24,
#  'вдохновение': 42,
#  'горячечный': 4,
#  'загромоздить': 17,
#  'значение': 171,
#  'испортить': 107,
#  'наконец': 1581,
#  'нелепо': 18,
#  'повиноваться': 46,
#  'противоположный': 89,
#  'рисунок': 53,
#  'смысл': 269,
#  'увидеть': 1138,
#  'хотеться': 704,
#  'ярко': 114,
#  'более': 1288,
#  'волна': 201,
#  'воображение': 203,
#  'вскоре': 250,
#  'дерзкий': 47,
#  'дьявольский': 7,
#  'заливать': 20,
#  'исполниться': 20,
#  'каждый': 1336,
#  'казаться': 2252,
#  'мрачный': 150,
#  'мысль': 1263,
#  'наваждение': 13,
#  'овладеть': 87,
#  'отступать': 44,
#  'радость': 597,
#  'решительность': 14,
#  'сметь': 305,
#  'сознание': 296,
#  'сомнение': 208,
#  'уверенность': 67,
#  'чувство': 1095,
#  'юношеский': 25,
#  'благий': 2,
#  'благодарность': 77,
#  'блаженство': 67,
#  'блистать': 82,
#  'божественный': 29,
#  'взор': 179,
#  'видение': 44,
#  'выситься': 16,
#  'грезиться': 7,
#  'грозный': 73,
#  'даль': 89,
#  'дева': 34,
#  'дивный': 38,
#  'дикий': 188,
#  'доселе': 33,
#  'жаждать': 29,
#  'жуткий': 22,
#  'звериный': 12,
#  'земной': 125,
#  'иоанн': 14,
#  'исполинский': 22,
#  'исступление': 53,
#  'клуб': 119,
#  'клубиться': 4,
#  'край': 369,
#  'красота': 313,
#  'крыло': 95,
#  'лазурь': 14,
#  'лик': 32,
#  'ликующий': 8,
#  'литургический': 2,
#  'лишь': 711,
#  'мать': 1384,
#  'младенец': 53,
#  'млеть': 18,
#  'могучий': 76,
#  'мысленно': 90,
#  'небывалый': 44,
#  'неизречённый': 6,
#  'несметный': 35,
#  'облако': 244,
#  'облачный': 11,
#  'одежда': 219,
#  'око': 63,
#  'отец': 1524,
#  'перед': 1646,
#  'поднимать': 215,
#  'потрясать': 41,
#  'преисполненный': 4,
#  'прелесть': 201,
#  'препоясать': 2,
#  'проступать': 17,
#  'простёртый': 7,
#  'раб': 68,
#  'радужный': 19,
#  'светозарный': 2,
#  'серафим': 8,
#  'сквозить': 23,
#  'смутный': 83,
#  'среди': 580,
#  'стоя': 116,
#  'счастливый': 643,
#  'творение': 15,
#  'творец': 23,
#  'торжествовать': 61,
#  'умственный': 49,
#  'хотя': 1126,
#  'целовать': 267,
#  'шкура': 28,
#  'эдемский': 3,
#  'являть': 14,
#  'ясность': 54,
#  'вдоль': 122,
#  'вновь': 163,
#  'догорать': 18,
#  'жаркий': 100,
#  'завешать': 3,
#  'лихорадочный': 31,
#  'ломать': 99,
#  'мокрый': 194,
#  'оплыть': 5,
#  'острить': 11,
#  'поспешность': 24,
#  'пылать': 40,
#  'раскалить': 26,
#  'текущий': 68,
#  'трястись': 68,
#  'щека': 382,
#  'бешено': 31,
#  'биться': 271,
#  'бледность': 38,
#  'губа': 635,
#  'давить': 60,
#  'звонок': 83,
#  'осыпать': 45,
#  'побежать': 315,
#  'пыль': 205,
#  'разноцветный': 49,
#  'божество': 15,
#  'вбежать': 71,
#  'воля': 409,
#  'гробовой': 16,
#  'душа': 1377,
#  'завершить': 6,
#  'заранее': 104,
#  'излить': 10,
#  'никто': 1261,
#  'ожидание': 247,
#  'окружать': 94,
#  'победительный': 4,
#  'превратиться': 70,
#  'сам': 5878,
#  'сей': 489,
#  'слух': 174,
#  'тишина': 343,
#  'труд': 568,
#  'близкий': 529,
#  'громоздиться': 13,
#  'дарить': 49,
#  'мечта': 182,
#  'покорить': 22,
#  'потеря': 54,
#  'противоположность': 27,
#  'расцветить': 2,
#  'сплошь': 50,
#  ...}

# %%
count_df = pd.DataFrame.from_dict(count_dict, 'index')
count_df
# Out:
#                  0
# безлюдный       41
# в            33040
# вера          1028
# вечный         237
# воскресение    114
# ...            ...
# кадно            1
# малейший         1
# кадетина         1
# вейдбрехт        1
# сичас            1
#
# [49412 rows x 1 columns]

# %%
count_df[count_df.index=='в']
# Out:
#        0
# в  33040

# %%
count_df['word'] = count_df.index.values
count_df = count_df.sort_values(by=[0, 'word'], ascending = [False, False])
count_df['number'] = range(1, 49413)
count_df
# Out:
#                  0         word  number
# и            42438            и       1
# в            33040            в       2
# не           29408           не       3
# он           27292           он       4
# на           25155           на       5
# ...            ...          ...     ...
# абогиня          1      абогиня   49408
# абиссинский      1  абиссинский   49409
# аберрация        1    аберрация   49410
# абдул            1        абдул   49411
# ааа              1          ааа   49412
#
# [49412 rows x 3 columns]

# %%
count_df[count_df.number==1000] # 274
# Out:
#             0      word  number
# чевенгур  249  чевенгур    1000

# %%
stop_words = count_df[:200].index.values
stop_words
# Out:
# array(['и', 'в', 'не', 'он', 'на', 'что', 'с', 'я', 'быть', 'а', 'она',
#        'как', 'это', 'к', 'то', 'но', 'сказать', 'вы', 'они', 'свой', 'у',
#        'по', 'ты', 'за', 'же', 'так', 'из', 'от', 'весь', 'тот', 'да',
#        'один', 'говорить', 'который', 'себя', 'этот', 'мы', 'человек',
#        'о', 'только', 'мочь', 'ещё', 'какой', 'знать', 'сам', 'всё',
#        'нет', 'бы', 'рука', 'мой', 'такой', 'когда', 'вот', 'уже',
#        'теперь', 'другой', 'стать', 'до', 'глаз', 'хотеть', 'или',
#        'слово', 'есть', 'ну', 'спросить', 'лицо', 'кто', 'ли', 'для',
#        'видеть', 'голова', 'день', 'где', 'дело', 'думать', 'опять',
#        'если', 'время', 'ничего', 'жизнь', 'два', 'после', 'идти',
#        'вдруг', 'ни', 'там', 'потом', 'раз', 'чтобы', 'дом', 'без',
#        'нибыть', 'пойти', 'жить', 'ваш', 'даже', 'под', 'большой', 'тут',
#        'очень', 'начать', 'чем', 'наш', 'хороший', 'год', 'бог', 'ж',
#        'надо', 'ведь', 'казаться', 'дать', 'глядеть', 'тоже', 'место',
#        'взять', 'уж', 'отвечать', 'сидеть', 'здесь', 'иванович', 'голос',
#        'любить', 'комната', 'делать', 'выйти', 'сделать', 'первый',
#        'смотреть', 'будто', 'стоять', 'потому', 'сейчас', 'должный',
#        'сердце', 'тогда', 'тем', 'земля', 'продолжать', 'перед', 'друг',
#        'иван', 'самый', 'через', 'сторона', 'час', 'новый', 'нога',
#        'чтоб', 'наконец', 'дверь', 'почти', 'минута', 'заметить',
#        'дорога', 'прийти', 'при', 'отец', 'несколько', 'хорошо',
#        'женщина', 'сила', 'свет', 'куда', 'над', 'жена', 'понимать',
#        'стол', 'город', 'три', 'лежать', 'между', 'совсем', 'иметь',
#        'мать', 'душа', 'можно', 'молодой', 'окно', 'подумать', 'ночь',
#        'каждый', 'твой', 'остаться', 'ребёнок', 'старый', 'ходить',
#        'всякий', 'более', 'чувствовать', 'господин', 'мысль', 'никто',
#        'посмотреть', 'б', 'точно', 'александр', 'всегда', 'никогда',
#        'немой', 'последний'], dtype=object)

# %%
df_pl = df[df.author == 'Андрей Платонович Платонов']
df_pl
# Out:
#                               author  \
# chunk_id
# 27651     Андрей Платонович Платонов
# 27652     Андрей Платонович Платонов
# 27653     Андрей Платонович Платонов
# 27654     Андрей Платонович Платонов
# 27655     Андрей Платонович Платонов
# ...                              ...
# 38665     Андрей Платонович Платонов
# 38666     Андрей Платонович Платонов
# 38667     Андрей Платонович Платонов
# 38668     Андрей Платонович Платонов
# 38669     Андрей Платонович Платонов
#
#                                                        text
# chunk_id
# 27651     состариться друг у окно казаться что этот своб...
# 27652     третий свисток я входить в ворота завод проход...
# 27653     в мастерская входить почти радостный ведь сейч...
# 27654     засыпать в печь металл пускать электромотор от...
# 27655     что то свистеть и смеяться что то запереть сил...
# ...                                                     ...
# 38665     только ломать стена в передний ряд можно первы...
# 38666     но оглушение иногда происходить и по другой пр...
# 38667     если ты начальник то ты открыть ворота сам мол...
# 38668     социальный вредность выстрел не так ясный но э...
# 38669     этот два сочинение явиться видимый причина бор...
#
# [11019 rows x 2 columns]

# %%
dict2 = {}
for text in df_pl['text']:
    words = text.split(' ')
    words_unique = np.unique(words)
    for word in words_unique:
        if word not in stop_words:
            if word in dict2.keys():
                dict2[word] += 1
            else: dict2[word] = 1 
dict2
# Out:
# {'будущее': 132,
#  'вечер': 252,
#  'внизу': 38,
#  'вступить': 17,
#  'далеко': 140,
#  'дожить': 12,
#  'именно': 59,
#  'история': 50,
#  'кругом': 74,
#  'музыка': 161,
#  'находиться': 245,
#  'неслышный': 9,
#  'отныне': 3,
#  'охватывать': 8,
#  'ощутимо': 1,
#  'проникать': 20,
#  'разлиться': 2,
#  'расположиться': 11,
#  'свобода': 39,
#  'святой': 28,
#  'состариться': 8,
#  'спокойствие': 31,
#  'счастие': 181,
#  'счастливый': 154,
#  'улица': 219,
#  'умилённый': 1,
#  'участник': 9,
#  'асфальтовый': 3,
#  'бежать': 133,
#  'биться': 69,
#  'будка': 69,
#  'виться': 5,
#  'вокруг': 130,
#  'ворота': 45,
#  'входить': 197,
#  'выступ': 3,
#  'двор': 322,
#  'дорожка': 15,
#  'завод': 95,
#  'заводский': 7,
#  'здание': 44,
#  'колоссальный': 1,
#  'контрольный': 13,
#  'литейный': 4,
#  'машина': 499,
#  'мимо': 119,
#  'мощный': 49,
#  'нумероваться': 1,
#  'огромный': 49,
#  'покорный': 15,
#  'проходить': 117,
#  'пульс': 8,
#  'ровный': 36,
#  'свисток': 23,
#  'слышать': 172,
#  'стена': 138,
#  'темп': 27,
#  'третий': 99,
#  'вагранный': 1,
#  'делаться': 64,
#  'железный': 154,
#  'загреметь': 10,
#  'задрожать': 4,
#  'закуривать': 11,
#  'здороваться': 16,
#  'игра': 42,
#  'иначе': 73,
#  'мастерская': 41,
#  'нельзя': 207,
#  'ожить': 18,
#  'печь': 107,
#  'плита': 21,
#  'пол': 181,
#  'пред': 20,
#  'работа': 532,
#  'радостный': 16,
#  'спуск': 10,
#  'товарищ': 740,
#  'усаживаться': 7,
#  'уход': 21,
#  'балка': 34,
#  'бесконечный': 23,
#  'бешеный': 16,
#  'вихрь': 31,
#  'воздух': 247,
#  'высокий': 164,
#  'газ': 27,
#  'гаснуть': 12,
#  'горчить': 2,
#  'гудеть': 35,
#  'двигатель': 16,
#  'жёлтый': 33,
#  'забываться': 23,
#  'засыпать': 28,
#  'зелёный': 22,
#  'клуб': 38,
#  'коварно': 1,
#  'лезть': 36,
#  'металл': 45,
#  'напор': 15,
#  'насмешливо': 4,
#  'неумолимо': 1,
#  'нефть': 10,
#  'нефтяной': 9,
#  'открывать': 86,
#  'плавиться': 3,
#  'пламя': 53,
#  'плясать': 12,
#  'подпотолочный': 1,
#  'пола': 18,
#  'пускать': 32,
#  'пыль': 42,
#  'рваться': 21,
#  'ревета': 2,
#  'ремень': 19,
#  'рот': 168,
#  'содрогаться': 10,
#  'солнце': 306,
#  'струя': 13,
#  'тяготить': 1,
#  'чадо': 23,
#  'щёлкать': 1,
#  'электромотор': 6,
#  'беспощадный': 3,
#  'визжать': 11,
#  'вихриться': 2,
#  'воля': 62,
#  'вырваться': 14,
#  'выть': 22,
#  'железо': 68,
#  'запереть': 23,
#  'зверски': 1,
#  'злоба': 31,
#  'камень': 97,
#  'медь': 14,
#  'молить': 4,
#  'мускул': 10,
#  'неуставать': 1,
#  'одиночество': 61,
#  'свистеть': 12,
#  'сильный': 90,
#  'смеяться': 85,
#  'снова': 234,
#  'сотрясать': 5,
#  'угрожать': 12,
#  'узел': 16,
#  'хитросплетённый': 1,
#  'яростно': 11,
#  'глянуть': 31,
#  'горячий': 84,
#  'готовый': 105,
#  'дружный': 5,
#  'застопорить': 2,
#  'змея': 10,
#  'илюша': 1,
#  'ловко': 5,
#  'мелькать': 1,
#  'монотонно': 4,
#  'мотор': 81,
#  'накалить': 4,
#  'намеднись': 1,
#  'насос': 37,
#  'неожиданно': 19,
#  'обращаться': 57,
#  'потемнеть': 18,
#  'проноровить': 1,
#  'слазить': 5,
#  'смолкнуть': 20,
#  'стенка': 12,
#  'тигль': 2,
#  'шов': 3,
#  'штука': 24,
#  'звать': 98,
#  'избегать': 3,
#  'иногда': 143,
#  'инструмент': 48,
#  'исправлять': 2,
#  'лестница': 19,
#  'монтёр': 10,
#  'назад': 130,
#  'небольшой': 146,
#  'неделя': 68,
#  'необходимость': 46,
#  'отказаться': 36,
#  'подавать': 88,
#  'подбадривать': 1,
#  'подвесить': 7,
#  'полезть': 20,
#  'поломка': 2,
#  'сначала': 151,
#  'электродвигатель': 2,
#  'ящик': 63,
#  'бродить': 48,
#  'бродяжка': 1,
#  'быстро': 164,
#  'весенний': 34,
#  'вновь': 72,
#  'вольный': 26,
#  'вон': 142,
#  'завыть': 4,
#  'захлопать': 3,
#  'захотеться': 22,
#  'звенящий': 3,
#  'зелень': 14,
#  'мучительный': 47,
#  'мёртвый': 316,
#  'небо': 249,
#  'неисправность': 1,
#  'неокрепший': 2,
#  'облако': 48,
#  'обнаружить': 35,
#  'омывать': 1,
#  'побить': 13,
#  'поле': 259,
#  'политься': 5,
#  'полуденный': 9,
#  'поток': 72,
#  'приводной': 7,
#  'птица': 113,
#  'пустяковый': 5,
#  'распростереть': 2,
#  'секунда': 18,
#  'сжаться': 23,
#  'снизу': 23,
#  'стекло': 66,
#  'страстно': 10,
#  'ток': 39,
#  'травка': 7,
#  'тянуться': 9,
#  'утопать': 10,
#  'цвета': 12,
#  'шуршать': 8,
#  'бегом': 11,
#  'вдвоём': 33,
#  'внимательно': 54,
#  'выливать': 1,
#  'горшок': 37,
#  'длинный': 79,
#  'жидкий': 28,
#  'искриться': 1,
#  'литься': 25,
#  'литьё': 3,
#  'наполняться': 10,
#  'несгораемый': 2,
#  'нестерпимый': 5,
#  'нести': 91,
#  'ослеплять': 2,
#  'осторожно': 79,
#  'приготовить': 32,
#  'соседний': 26,
#  'сразу': 406,
#  'стоить': 311,
#  'форма': 52,
#  'фыркать': 1,
#  'хватать': 109,
#  'шипеть': 12,
#  'шток': 4,
#  'яркий': 10,
#  'блеск': 4,
#  'болванка': 1,
#  'ваня': 14,
#  'гноиться': 2,
#  'двое': 108,
#  'ждать': 136,
#  'игнат': 105,
#  'корявый': 3,
#  'кровь': 122,
#  'налитой': 2,
#  'наполнять': 3,
#  'недавно': 38,
#  'новичок': 1,
#  'около': 201,
#  'опорожнить': 6,
#  'ослепнуть': 12,
#  'покуривать': 4,
#  'постоянно': 69,
#  'поступить': 39,
#  'пузырчатый': 1,
#  'работать': 490,
#  'рабочий': 207,
#  'регулировать': 7,
#  'трое': 76,
#  'вонючий': 3,
#  'ворчать': 3,
#  'гуща': 37,
#  'действительно': 82,
#  'дым': 53,
#  'залаживаться': 1,
#  'милость': 12,
#  'недовольный': 19,
#  'обед': 65,
#  'обыкновенно': 34,
#  'огонь': 340,
#  'поговорить': 33,
#  'пофыркивать': 1,
#  'растяпа': 1,
#  'старшой': 2,
#  'стерва': 22,
#  'часто': 85,
#  'черта': 72,
#  'чихать': 5,
#  'шабаш': 3,
#  'белый': 93,
#  'бич': 3,
#  'вверх': 40,
#  'взмахивать': 2,
#  'высоко': 36,
#  'глухой': 62,
#  'зачем': 244,
#  'измеритель': 1,
#  'крыша': 53,
#  'ладиться': 2,
#  'мгновение': 41,
#  'обернуться': 44,
#  'оборот': 19,
#  'огненный': 6,
#  'опускать': 29,
#  'повториться': 7,
#  'подойти': 177,
#  'полоса': 19,
#  'прислушаться': 32,
#  'рвануться': 8,
#  'свистящий': 1,
#  'свод': 4,
#  'тяжело': 28,
#  'увидеть': 357,
#  'удар': 73,
#  'ухнуть': 1,
#  'уходить': 379,
#  'четыре': 191,
#  'число': 50,
#  'чудесно': 4,
#  'десять': 122,
#  'инерция': 12,
#  'инстинктивно': 3,
#  'испускать': 6,
#  'медленно': 124,
#  'метнуться': 1,
#  'немного': 213,
#  'обхватить': 12,
#  'остановиться': 155,
#  'охлаждаться': 3,
#  'повертеться': 1,
#  'прервать': 7,
#  'присесть': 19,
#  'радиус': 1,
#  'раскалить': 6,
#  'расходиться': 12,
#  'рукоятка': 15,
#  'страшный': 76,
#  'схватить': 42,
#  'упавший': 11,
#  'шаг': 84,
#  'ах': 80,
#  'бак': 10,
#  'вздыхать': 38,
#  'вода': 396,
#  'выкинуть': 7,
#  'гореть': 154,
#  'деньга': 114,
#  'догадаться': 65,
#  'заместо': 4,
#  'ладный': 77,
#  'мгновенно': 31,
#  'мучитель': 8,
#  'напустить': 3,
#  'окаянный': 5,
#  'пара': 87,
#  'погубить': 14,
#  'попасть': 78,
#  'превратиться': 25,
#  'проклятый': 31,
#  'разорвать': 8,
#  'расплавить': 4,
#  'толпа': 30,
#  'треклятый': 1,
#  'вниз': 103,
#  'выбрасывать': 1,
#  'грызть': 10,
#  'двигать': 13,
#  'зуб': 44,
#  'котёл': 61,
#  'молча': 182,
#  'остыть': 37,
#  'паровой': 14,
#  'похожий': 103,
#  'скорее': 115,
#  'скоро': 236,
#  'спина': 76,
#  'топка': 46,
#  'узор': 4,
#  'шлак': 11,
#  'выставить': 6,
#  'вытирать': 25,
#  'замирать': 22,
#  'заправить': 7,
#  'невидящий': 5,
#  'неподвижно': 50,
#  'носок': 6,
#  'обмотать': 4,
#  'обуглить': 3,
#  'палец': 81,
#  'плакать': 195,
#  'подле': 6,
#  'полчаса': 22,
#  'пустить': 68,
#  'пятка': 3,
#  'сварить': 21,
#  'судорога': 8,
#  'тряпка': 24,
#  'упереться': 12,
#  'бегать': 19,
#  'бормотать': 73,
#  'брат': 171,
#  'гунь': 4,
#  'дышать': 134,
#  'живот': 104,
#  'зажигать': 15,
#  'лампа': 124,
#  'ложиться': 81,
#  'маленький': 345,
#  'мешать': 53,
#  'пухлый': 4,
#  'ребятишки': 21,
#  'садиться': 156,
#  'сон': 274,
#  'спать': 432,
#  'сползать': 5,
#  'таракан': 14,
#  'туго': 14,
#  'тяжко': 30,
#  'ужин': 59,
#  'храпеть': 16,
#  'давно': 316,
#  'забыть': 216,
#  'записать': 31,
#  'захотеть': 78,
#  'книга': 131,
#  'кондрат': 17,
#  'конец': 249,
#  'листик': 6,
#  'маркун': 27,
#  'мир': 351,
#  'найти': 221,
#  'познать': 5,
#  'прочесть': 30,
#  'разве': 87,
#  'суметь': 56,
#  'тело': 578,
#  'фёдор': 95,
#  'близко': 84,
#  'вспомнить': 152,
#  'вчера': 51,
#  'девушка': 144,
#  'написать': 117,
#  'невеста': 56,
#  'низкий': 51,
#  'отчий': 180,
#  'плохо': 79,
#  'сегодня': 118,
#  'февраль': 4,
#  'холодно': 19,
#  'хотеться': 86,
#  'бумага': 106,
#  'вращение': 5,
#  'вынуть': 72,
#  'завизжать': 3,
#  'изогнутый': 1,
#  'клоп': 9,
#  'крутой': 13,
#  'лист': 62,
#  'мальчик': 248,
#  'мороз': 14,
#  'мощь': 16,
#  'начертить': 1,
#  'паровоз': 359,
#  'печурка': 3,
#  'размах': 5,
#  'сесть': 169,
#  'снять': 86,
#  'спираль': 7,
#  'толстой': 14,
#  'труба': 66,
#  'хранить': 43,
#  'хребет': 2,
#  'чертёж': 16,
#  'шесть': 58,
#  'щека': 50,
#  'борьба': 45,
#  'единица': 3,
#  'значит': 186,
#  'количество': 30,
#  'материя': 34,
#  'освободиться': 11,
#  'поворот': 10,
#  'потерять': 60,
#  'превратить': 14,
#  'предел': 24,
#  'природа': 210,
#  'пусть': 256,
#  'труд': 228,
#  'угол': 55,
#  'шкив': 8,
#  'вагон': 172,
#  'ветер': 308,
#  'вскинуть': 3,
#  'встать': 154,
#  'довольно': 39,
#  'еле': 58,
#  'завязать': 8,
#  'звезда': 126,
#  'крюк': 10,
#  'любой': 84,
#  'метель': 22,
#  'налететь': 3,
#  'опереться': 12,
#  'печка': 95,
#  'пробивать': 4,
#  'разыгрываться': 3,
#  'рвать': 34,
#  'снег': 124,
#  'станок': 10,
#  'сугроб': 10,
#  'тендерный': 5,
#  'тихий': 165,
#  'человечество': 105,
#  'архимед': 3,
#  'белые': 29,
#  'берег': 116,
#  'весёлый': 55,
#  'вздрогнуть': 18,
#  'вселенная': 50,
#  'дальний': 146,
#  'забытый': 40,
#  'искать': 148,
#  'красавица': 11,
#  'кроткий': 53,
#  'море': 102,
#  'ночной': 135,
#  'опора': 4,
#  'очнуться': 28,
#  'пароход': 16,
#  'позабыть': 28,
#  'приехать': 109,
#  'родный': 84,
#  'точка': 49,
#  'тёплый': 144,
#  'утро': 173,
#  'вес': 42,
#  'вылететь': 9,
#  'выходить': 206,
#  'гнездо': 13,
#  'земной': 58,
#  'качнуть': 2,
#  'масса': 127,
#  'нарушить': 5,
#  'нужно': 321,
#  'одинаковый': 19,
#  'поверхность': 45,
#  'ручка': 24,
#  'рычаг': 19,
#  'связать': 17,
#  'сопротивление': 19,
#  'тяготение': 7,
#  'центр': 46,
#  'перевесить': 1,
#  'пересилить': 1,
#  'повернуть': 30,
#  'точный': 72,
#  'ухватиться': 7,
#  'буря': 36,
#  'величина': 10,
#  'водяной': 33,
#  'вычертить': 1,
#  'грань': 3,
#  'дрожать': 46,
#  'кривая': 8,
#  'линейка': 6,
#  'линия': 69,
#  'находить': 38,
#  'оживлять': 7,
#  'окружность': 4,
#  'песня': 97,
#  'повесить': 12,
#  'светлый': 62,
#  'сеть': 9,
#  'тонкий': 44,
#  'циркуль': 1,
#  'больший': 193,
#  'вал': 14,
#  'второй': 191,
#  'вырабатывать': 4,
#  'давать': 428,
#  'естественный': 16,
#  'малый': 97,
#  'неограниченный': 1,
#  'непосредственно': 9,
#  'общий': 198,
#  'одновременно': 42,
#  'определённый': 17,
#  'против': 150,
#  'соответственно': 5,
#  'съедать': 14,
#  'таков': 13,
#  'увеличиться': 9,
#  'устроить': 53,
#  'энергия': 64,
#  'возрастать': 3,
#  'мощность': 13,
#  'нагнуться': 10,
#  'последовательно': 4,
#  'пять': 123,
#  'расходоваться': 2,
#  'система': 41,
#  'следовательно': 14,
#  'сцепить': 5,
#  'турбина': 12,
#  'ускорение': 9,
#  'шестикратное': 1,
#  'шестой': 8,
#  'закон': 61,
#  'крепость': 22,
#  'ложь': 16,
#  'неожиданный': 6,
#  'оправдать': 10,
#  'опыт': 32,
#  'поэтому': 170,
#  'пройти': 246,
#  'прочный': 29,
#  'способность': 13,
#  'теория': 16,
#  'бесконечность': 18,
#  'бить': 159,
#  'возрастание': 1,
#  'всемогущество': 1,
#  'жерло': 3,
#  'квадратный': 5,
#  'кубический': 5,
#  'океан': 41,
#  'перекачать': 2,
#  'полюс': 5,
#  'построить': 52,
#  'радость': 156,
#  'спустить': 13,
#  'считать': 157,
#  'турбин': 6,
#  'упоение': 4,
#  'цвести': 4,
#  'часы': 55,
#  'южный': 23,
#  'близкий': 151,
#  'вьюга': 15,
#  'далёкий': 353,
#  'жалеть': 62,
#  'жалость': 30,
#  'живой': 413,
#  'затрястись': 3,
#  'любим': 11,
#  'любовь': 278,
#  'невозвратный': 4,
#  'неизвестный': 147,
#  'постилка': 4,
#  'пугать': 26,
#  'слушать': 258,
#  'ставень': 13,
#  'умерший': 69,
#  'чужой': 186,
#  'бессильный': 9,
#  'быстрый': 31,
#  'взмах': 5,
#  'закрываться': 8,
#  'запутать': 1,
#  'изуродовать': 8,
#  'мелочь': 26,
#  'молчать': 213,
#  'незаметный': 8,
#  'нечаянный': 16,
#  'ничтожный': 23,
#  'ошибка': 25,
#  'пора': 236,
#  'преступление': 4,
#  'сжать': 27,
#  'совесть': 33,
#  'столкнуть': 2,
#  'сторониться': 6,
#  'страдание': 56,
#  'страх': 90,
#  'вверху': 9,
#  'видный': 105,
#  'испуганный': 10,
#  'крикнуть': 76,
#  'потечь': 8,
#  'прорываться': 1,
#  'рубашка': 50,
#  'серый': 54,
#  'сутки': 82,
#  'туча': 33,
#  'ударить': 65,
#  'холодный': 66,
#  'луна': 63,
#  'отражённый': 3,
#  'планета': 11,
#  'поглощать': 5,
#  'превращать': 9,
#  'про': 282,
#  'разумный': 34,
#  'рядом': 121,
#  'светиться': 27,
#  'сколько': 185,
#  'существо': 105,
#  'тёмный': 182,
#  'вернуться': 179,
#  'газовый': 10,
#  'домой': 142,
#  'замереть': 36,
#  'искорка': 1,
#  'красный': 129,
#  'лечь': 185,
#  'месяц': 119,
#  'модель': 5,
#  'нужный': 195,
#  'потухнуть': 36,
#  'приблизительный': 5,
#  'пробовать': 50,
#  'размер': 22,
#  'раскопать': 5,
#  'сарай': 64,
#  'согнуть': 3,
#  'спрятать': 26,
#  'фитилёк': 1,
#  'безграничный': 2,
#  'безумный': 36,
#  'верить': 100,
#  'многие': 62,
#  'молотый': 10,
#  'немощный': 10,
#  'победить': 33,
#  'болото': 24,
#  'везде': 42,
#  'вера': 66,
#  'весна': 55,
#  'детство': 80,
#  'закат': 12,
#  'лужа': 6,
#  'молиться': 24,
#  'одиноко': 19,
#  'поставить': 109,
#  'прошлый': 36,
#  'раб': 17,
#  'служить': 80,
#  'тишина': 148,
#  'дрова': 43,
#  'запирать': 9,
#  'заработать': 26,
#  'играть': 183,
#  'купить': 76,
#  'погремушка': 1,
#  'полдень': 61,
#  'привыкнуть': 147,
#  'сгружать': 3,
#  'слепец': 13,
#  'сосед': 53,
#  'станция': 173,
#  'убежать': 23,
#  'убиться': 2,
#  'уметь': 73,
#  'влажный': 39,
#  'выше': 45,
#  'избушка': 57,
#  'край': 120,
#  'красноватый': 2,
#  'лесной': 21,
#  'лозина': 2,
#  'маячить': 2,
#  'муть': 4,
#  'подниматься': 49,
#  'подходить': 164,
#  'ползти': 30,
#  'понять': 232,
#  'прохладный': 44,
#  'синий': 58,
#  'скрытый': 36,
#  'сторож': 72,
#  'сумрак': 49,
#  'темнеть': 15,
#  'туман': 35,
#  'чуть': 55,
#  'юбка': 30,
#  'боль': 45,
#  'завтра': 130,
#  'затаиться': 3,
#  'мука': 29,
#  'неслышно': 17,
#  'прилечь': 28,
#  'пропасть': 110,
#  'слыхать': 40,
#  'спасть': 195,
#  'странник': 31,
#  'улыбаться': 130,
#  'восток': 26,
#  'вскочить': 32,
#  'жаркий': 11,
#  'мгновенный': 20,
#  'накаляться': 3,
#  'прилипаться': 1,
#  'проснуться': 160,
#  'скула': 4,
#  'убегать': 20,
#  'утренний': 45,
#  'великий': 101,
#  'восторг': 24,
#  'издалёка': 17,
#  'морозно': 1,
#  'оборваться': 4,
#  'отдать': 93,
#  'просторный': 17,
#  'прямо': 75,
#  'светло': 6,
#  'тихо': 296,
#  'узнать': 169,
#  'боченок': 1,
#  'ведро': 44,
#  'воронка': 5,
#  'вылить': 3,
#  'засмеяться': 55,
#  'кран': 26,
#  'одинокий': 107,
#  'привинтить': 2,
#  'принести': 122,
#  'пристроить': 1,
#  'пята': 1,
#  'смазать': 6,
#  'упираться': 13,
#  'чашка': 30,
#  'дурак': 79,
#  'лес': 135,
#  'махать': 24,
#  'ненавидеть': 14,
#  'позвать': 82,
#  'рассказать': 50,
#  'гордый': 8,
#  'гром': 21,
#  'гудок': 38,
#  'загудеть': 16,
#  'зачерпнуть': 1,
#  'ликующий': 6,
#  'неутомимость': 3,
#  'полный': 176,
#  'спокойный': 67,
#  'уверенный': 20,
#  'человеческий': 91,
#  'электричество': 91,
#  'всасывание': 1,
#  'крутиться': 6,
#  'наращивать': 1,
#  'подливать': 2,
#  'реветь': 16,
#  'резать': 21,
#  'слышный': 109,
#  'стонать': 18,
#  'ход': 170,
#  'вести': 126,
#  'дрожь': 7,
#  'задымиться': 1,
#  'никакой': 134,
#  'ожидание': 56,
#  'подпрыгивать': 3,
#  'подшипник': 9,
#  'родиться': 82,
#  'тревога': 47,
#  'трястись': 8,
#  'визг': 7,
#  'вращаться': 21,
#  'выскочить': 8,
#  'деревянный': 116,
#  'зарыться': 4,
#  'кусок': 68,
#  'лопнуть': 14,
#  'нижний': 33,
#  'оторваться': 9,
#  'пробить': 7,
#  'расти': 165,
#  'скорость': 87,
#  'увеличивать': 8,
#  'голый': 84,
#  'загораживать': 5,
#  'низко': 27,
#  'ничто': 92,
#  'опустить': 57,
#  'открыться': 33,
#  'оттого': 63,
#  'ранний': 167,
#  'растворить': 2,
#  'уничтожить': 45,
#  'хворостина': 11,
#  'шевелить': 23,
#  'видно': 121,
#  'домик': 16,
#  'забор': 29,
#  'запор': 6,
#  'калитка': 16,
#  'оттуда': 175,
#  'подпорка': 1,
#  'посидеть': 35,
#  'флигель': 2,
#  'волчек': 10,
#  'долго': 250,
#  'навстречу': 72,
#  'поглядеть': 178,
#  'спешить': 108,
#  'трава': 241,
#  'увидать': 4,
#  'утром': 119,
#  'человечий': 4,
#  'высота': 87,
#  'голубой': 16,
#  'звонить': 36,
#  'колокол': 29,
#  'неяркий': 2,
#  'приподниматься': 4,
#  'рассеиваться': 14,
#  'репей': 5,
#  'семафор': 7,
#  'сжиматься': 8,
#  'тепло': 133,
#  'тонко': 6,
#  'церква': 1,
#  'шум': 85,
#  'двинуться': 16,
#  'дума': 28,
#  'лопух': 40,
#  'наклониться': 28,
#  'отдохнуть': 66,
#  'открытый': 110,
#  'притихнуть': 6,
#  'радовать': 9,
#  'собака': 75,
#  'сырость': 31,
#  'угнетать': 5,
#  'волчок': 7,
#  'давить': 16,
#  'забывать': 50,
#  'корень': 33,
#  'радоваться': 75,
#  'сзади': 33,
#  'спереди': 10,
#  'сырой': 40,
#  'тьма': 144,
#  'чернота': 9,
#  'беситься': 4,
#  'больной': 74,
#  'великан': 5,
#  'гоняться': 2,
#  'грызться': 1,
#  'здоровый': 56,
#  'кость': 111,
#  'свадьба': 18,
#  'собачий': 6,
#  'хозяин': 124,
#  'чайка': 4,
#  'щи': 39,
#  'бледный': 40,
#  'видение': 17,
#  'кротость': 16,
#  'оземь': 2,
#  'полюбить': 56,
#  'приходить': 146,
#  'пылкий': 1,
#  'ребята': 58,
#  'уважение': 26,
#  'хвост': 31,
#  'доска': 51,
#  'полнолуние': 1,
#  'попробовать': 66,
#  'потянуться': 10,
#  'холодное': 18,
#  'досказать': 3,
#  'нечего': 117,
#  'пустота': 55,
#  'узнавать': 42,
#  'хоть': 177,
#  'вечером': 133,
#  'кормить': 92,
#  'одевать': 15,
#  'перестать': 120,
#  'помолчать': 26,
#  'растерять': 4,
#  'сидя': 14,
#  'умориться': 41,
#  'вдалеке': 87,
#  'встретить': 86,
#  'гора': 187,
#  'дождаться': 32,
#  'издохнуть': 4,
#  'каменный': 42,
#  'кобель': 5,
#  'либо': 145,
#  'любящий': 13,
#  'оставаться': 146,
#  'пустой': 276,
#  ...}

# %%
df2 = pd.DataFrame.from_dict(dict2, 'index')
df2
# Out:
#                    0
# будущее          132
# вечер            252
# внизу             38
# вступить          17
# далеко           140
# ...              ...
# доработаться       1
# методический       1
# пролёт             1
# рапп               1
# санкционировать    1
#
# [23388 rows x 1 columns]

# %%
df2['word'] = df2.index.values
df2 = df2.sort_values(by=[0,'word'], ascending = [False, True])
df2['number'] = range(1, 23389)
df2
# Out:
#             0      word  number
# товарищ   740   товарищ       1
# тело      578      тело       2
# работа    532    работа       3
# ответить  518  ответить       4
# машина    499    машина       5
# ...       ...       ...     ...
# ящичек      1    ящичек   23384
# ёж          1        ёж   23385
# ёжик        1      ёжик   23386
# ёжиться     1   ёжиться   23387
# ёмкость     1   ёмкость   23388
#
# [23388 rows x 3 columns]

# %%
np.mean([2**i/i for i in range(1,21)])
# Out:
# 5557.118722378413
